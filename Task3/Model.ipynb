# %%
# import pandas as pd
import pandas as pd
# import numpy as np
import numpy as np
# import sklearn
import sklearn
# import seaborn as sns
import seaborn as sns
# import matplotlib.pyplot as pt
import matplotlib.pyplot as pt
# %matplotlib inline
# %matplotlib inline

# %%
# file_path="Housing.csv"
file_path="Housing.csv"
# Housing_df=pd.read_csv(file_path)
Housing_df=pd.read_csv(file_path)

# %%
# Housing_df.head(10)
Housing_df.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
# Housing_df.shape
Housing_df.shape
# Out:
# (545, 13)

# %%
# Housing_df.info()
Housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
# sns.heatmap(data=Housing_df.isnull(), cmap="Blues", cbar=False,yticklabels=False)
sns.heatmap(data=Housing_df.isnull(), cmap="Blues", cbar=False,yticklabels=False)
# Out:
# <Axes: >

# %%
# Housing_df.drop_duplicates(inplace=True)
Housing_df.drop_duplicates(inplace=True)

# %%
# Housing_df.shape
Housing_df.shape
# Out:
# (545, 13)

# %%
# sns.boxplot(data=Housing_df)
sns.boxplot(data=Housing_df)
# Out:
# <Axes: >

# %%
# Q1=Housing_df["price"].quantile(0.25)
Q1=Housing_df["price"].quantile(0.25)
# Q3=Housing_df["price"].quantile(0.75)
Q3=Housing_df["price"].quantile(0.75)
# IQR=Q3-Q1
IQR=Q3-Q1
# lowerBound=Q1-1.5*IQR
lowerBound=Q1-1.5*IQR
# UpperBound=Q3+1.5*IQR
UpperBound=Q3+1.5*IQR
# Housing_df=Housing_df[(Housing_df["price"]>=lowerBound) & (Housing_df["price"]<=UpperBound)]
Housing_df=Housing_df[(Housing_df["price"]>=lowerBound) & (Housing_df["price"]<=UpperBound)]

# %%
# sns.boxplot(data=Housing_df)
sns.boxplot(data=Housing_df)
# Out:
# <Axes: >

# %%
# Housing_df.shape
Housing_df.shape
# Out:
# (530, 13)

# %%
# sns.heatmap(data=Housing_df.isnull(), cmap="Blues",cbar=False,yticklabels=False )
sns.heatmap(data=Housing_df.isnull(), cmap="Blues",cbar=False,yticklabels=False )
# Out:
# <Axes: >

# %%
# objcat=[
objcat=[
# "furnishingstatus", "prefarea", "airconditioning", "hotwaterheating", "basement",
"furnishingstatus", "prefarea", "airconditioning", "hotwaterheating", "basement",
# "guestroom", "mainroad"
"guestroom", "mainroad"
# ]
]
# for col in objcat:
for col in objcat:
#   Housing_df[col]=Housing_df[col].astype("category")
  Housing_df[col]=Housing_df[col].astype("category")

# %%
# Housing_df.select_dtypes("category").columns
Housing_df.select_dtypes("category").columns
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
# Furnishingstatus=pd.get_dummies(Housing_df["furnishingstatus"], drop_first=True)
Furnishingstatus=pd.get_dummies(Housing_df["furnishingstatus"], drop_first=True)
# Furnishingstatus=Furnishingstatus.astype("int")
Furnishingstatus=Furnishingstatus.astype("int")
# Prefarea =pd.get_dummies(Housing_df["prefarea"], drop_first=True)
Prefarea =pd.get_dummies(Housing_df["prefarea"], drop_first=True)
# Prefarea=Prefarea.astype("int")
Prefarea=Prefarea.astype("int")
# Airconditioning =pd.get_dummies(Housing_df["airconditioning"], drop_first=True)
Airconditioning =pd.get_dummies(Housing_df["airconditioning"], drop_first=True)
# Airconditioning =Airconditioning.astype("int")
Airconditioning =Airconditioning.astype("int")
# Hotwaterheating=pd.get_dummies(Housing_df["hotwaterheating"], drop_first=True)
Hotwaterheating=pd.get_dummies(Housing_df["hotwaterheating"], drop_first=True)
# Hotwaterheating=Hotwaterheating.astype("int")
Hotwaterheating=Hotwaterheating.astype("int")
# Basement=pd.get_dummies(Housing_df["basement"], drop_first=True)
Basement=pd.get_dummies(Housing_df["basement"], drop_first=True)
# Basement=Basement.astype("int")
Basement=Basement.astype("int")
# Guestroom=pd.get_dummies(Housing_df["guestroom"], drop_first=True)
Guestroom=pd.get_dummies(Housing_df["guestroom"], drop_first=True)
# Guestroom=Guestroom.astype("int")
Guestroom=Guestroom.astype("int")
# Mainroad=pd.get_dummies(Housing_df["mainroad"], drop_first=True)
Mainroad=pd.get_dummies(Housing_df["mainroad"], drop_first=True)
# Mainroad=Mainroad.astype("int")
Mainroad=Mainroad.astype("int")

# %%
# Housing_df=pd.concat([Housing_df, Furnishingstatus,Prefarea, Airconditioning,Hotwaterheating,Basement,Guestroom, Mainroad ], axis=1)
Housing_df=pd.concat([Housing_df, Furnishingstatus,Prefarea, Airconditioning,Hotwaterheating,Basement,Guestroom, Mainroad ], axis=1)
# Housing_df.shape
Housing_df.shape
# Out:
# (530, 21)

# %%
# Housing_df
Housing_df
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 15   9100000  6000         4          1        2      yes        no      yes
# 16   9100000  6600         4          2        2      yes       yes      yes
# 17   8960000  8500         3          2        4      yes        no       no
# 18   8890000  4600         3          2        2      yes       yes       no
# 19   8855000  6420         3          2        2      yes        no       no
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
# Housing_df.drop(["furnishingstatus", "prefarea", "airconditioning", "hotwaterheating", "basement",
Housing_df.drop(["furnishingstatus", "prefarea", "airconditioning", "hotwaterheating", "basement",
# "guestroom", "mainroad"], inplace=True, axis=1)
"guestroom", "mainroad"], inplace=True, axis=1)

# %%
# Housing_df.shape
Housing_df.shape
# Out:
# (530, 14)

# %%
# Housing_df
Housing_df
# Out:
#        price  area  bedrooms  bathrooms  stories  parking  semi-furnished  \
# 15   9100000  6000         4          1        2        2               1
# 16   9100000  6600         4          2        2        1               0
# 17   8960000  8500         3          2        4        2               0
# 18   8890000  4600         3          2        2        2               0
# 19   8855000  6420         3          2        2        1               1
# ..       ...   ...       ...        ...      ...      ...             ...
# 540  1820000  3000         2          1        1        2               0
# 541  1767150  2400         3          1        1        0               1
# 542  1750000  3620         2          1        1        0               0
# 543  1750000  2910         3          1        1        0               0
# 544  1750000  3850         3          1        2        0               0
#
#      unfurnished  yes  yes  yes  yes  yes  yes
# ...

# %%
# Housing_df.info()
Housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 530 entries, 15 to 544
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   price           530 non-null    int64
#  1   area            530 non-null    int64
#  2   bedrooms        530 non-null    int64
#  3   bathrooms       530 non-null    int64
#  4   stories         530 non-null    int64
#  5   parking         530 non-null    int64
#  6   semi-furnished  530 non-null    int64
#  7   unfurnished     530 non-null    int64
#  8   yes             530 non-null    int64
#  9   yes             530 non-null    int64
#  10  yes             530 non-null    int64
#  11  yes             530 non-null    int64
#  12  yes             530 non-null    int64
#  13  yes             530 non-null    int64
# dtypes: int64(14)
# memory usage: 62.1 KB

# %%
# Housing_df.columns.values[8]="Prefarea"
Housing_df.columns.values[8]="Prefarea"
# Housing_df.columns.values[9]="Airconditioning"
Housing_df.columns.values[9]="Airconditioning"
# Housing_df.columns.values[10]="Hotwaterheating"
Housing_df.columns.values[10]="Hotwaterheating"
# Housing_df.columns.values[11]="Basement"
Housing_df.columns.values[11]="Basement"
# Housing_df.columns.values[12]="Guestroom"
Housing_df.columns.values[12]="Guestroom"
# Housing_df.columns.values[13]="Mainroad"
Housing_df.columns.values[13]="Mainroad"

# %%
# Housing_df
Housing_df
# Out:
#        price  area  bedrooms  bathrooms  stories  parking  semi-furnished  \
# 15   9100000  6000         4          1        2        2               1
# 16   9100000  6600         4          2        2        1               0
# 17   8960000  8500         3          2        4        2               0
# 18   8890000  4600         3          2        2        2               0
# 19   8855000  6420         3          2        2        1               1
# ..       ...   ...       ...        ...      ...      ...             ...
# 540  1820000  3000         2          1        1        2               0
# 541  1767150  2400         3          1        1        0               1
# 542  1750000  3620         2          1        1        0               0
# 543  1750000  2910         3          1        1        0               0
# 544  1750000  3850         3          1        2        0               0
#
#      unfurnished  Prefarea  Airconditioning  Hotwaterheating  Basement  \
# ...

# %%
# x=Housing_df.drop(["price"], axis=1)
x=Housing_df.drop(["price"], axis=1)
# y=Housing_df["price"]
y=Housing_df["price"]

# %%
# from sklearn import preprocessing
from sklearn import preprocessing
# pre_process=preprocessing.StandardScaler().fit(x)
pre_process=preprocessing.StandardScaler().fit(x)

# transform_x=pre_process.fit_transform(x)
transform_x=pre_process.fit_transform(x)

# %%
# from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split

# x_train, x_test, y_train, y_test=train_test_split(transform_x,y, test_size=0.2, random_state=101)
x_train, x_test, y_train, y_test=train_test_split(transform_x,y, test_size=0.2, random_state=101)

# %%
# transform_x
transform_x
# Out:
# array([[ 0.45260931,  1.44774876, -0.56125391, ...,  1.37128946,
#         -0.46131838,  0.41228379],
#        [ 0.74197643,  1.44774876,  1.59428648, ...,  1.37128946,
#          2.16770033,  0.41228379],
#        [ 1.65830564,  0.07755797,  1.59428648, ..., -0.72924064,
#         -0.46131838,  0.41228379],
#        ...,
#        [-0.69521361, -1.29263282, -0.56125391, ..., -0.72924064,
#         -0.46131838,  0.41228379],
#        [-1.03763137,  0.07755797, -0.56125391, ..., -0.72924064,
#         -0.46131838, -2.42551374],
#        [-0.58428954,  0.07755797, -0.56125391, ..., -0.72924064,
#         -0.46131838,  0.41228379]])

# %%
# from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
# lreg=LinearRegression()
lreg=LinearRegression()
# lreg.fit(x_train, y_train)
lreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# y_train
y_train
# Out:
# 400    3500000
# 303    4200000
# 382    3570000
# 424    3360000
# 63     7035000
#         ...
# 331    3920000
# 408    3430000
# 90     6440000
# 352    3780000
# 538    1890000
# Name: price, Length: 424, dtype: int64

# %%
# from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import mean_squared_error, mean_absolute_error
# predicted_prices=lreg.predict(x_test)
predicted_prices=lreg.predict(x_test)
# print(predicted_prices)
print(predicted_prices)
# Out:
# [5324228.19539661 4444094.19311406 5766574.00549972 6170683.2517071
#  6437729.07036897 3906805.79501184 4577167.43309725 6293645.44604566
#  6123167.20728645 3621857.28686342 3224589.14255076 3918197.57785359
#  3512481.39674042 4205162.23368545 4071248.6510702  4620242.33359152
#  4771066.7005264  3015311.6396445  4533380.14083659 4652684.95350764
#  6303998.97750849 2579437.47590625 4023179.64321809 5693099.4447187
#  3952924.35157274 4844833.67467739 4334695.67703218 3831647.7452297
#  4809307.55017051 3964596.05996788 6538405.00557069 6525946.23361452
#  6530520.69002608 3711868.35971117 5376399.70895852 7613698.20021335
#  3707948.52536539 5538531.62219309 4916570.1764446  5768057.63670053
#  5492215.13319867 6679662.43934899 3282673.83549548 2972817.63800964
#  4143618.90298701 3279339.87943678 6865116.12732729 2775798.79244319
#  6871365.20922319 3373862.90287211 4294487.97221259 5763421.84085383
#  3077120.26542254 2818509.90569877 7299506.70633    3075987.79966439
# ...

# %%
# print("Model Evaluation")
print("Model Evaluation")
# print("--"*30)
print("--"*30)

# mse=mean_squared_error(y_test, predicted_prices)
mse=mean_squared_error(y_test, predicted_prices)
# rmse=np.sqrt(mse)
rmse=np.sqrt(mse)
# mae=mean_absolute_error(y_test, predicted_prices)
mae=mean_absolute_error(y_test, predicted_prices)
# print(f"MSE {mse: .2f}")
print(f"MSE {mse: .2f}")
# print(f"RMSE {rmse: .2f}")
print(f"RMSE {rmse: .2f}")
# print(f"MAE {mae: .2f}")
print(f"MAE {mae: .2f}")
# Out:
# Model Evaluation
# ------------------------------------------------------------
# MSE  839196306782.09
# RMSE  916076.58
# MAE  680152.52

# %%
# from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor
# Greg=GradientBoostingRegressor()
Greg=GradientBoostingRegressor()
# Greg.fit(x_train,y_train) 
Greg.fit(x_train,y_train) 
# y_predict=Greg.predict(x_test)
y_predict=Greg.predict(x_test)
# print(y_predict)
print(y_predict)
# Out:
# [4009296.90135896 4977026.74041375 5201892.86296543 5624572.64631481
#  7213325.84956351 4039827.82152219 4722673.52083395 7567754.16161721
#  5167126.86501252 4255244.61770952 4221137.33153308 3596609.65174521
#  3232560.58856672 4308360.9339883  3877650.89569649 4639198.43761079
#  4832932.30856336 3373105.82232651 4152660.96487338 4938236.79039906
#  6027018.66784044 3223121.0604911  4068502.20790955 5413280.48701675
#  4491027.84471577 4670417.87385407 4642746.04084306 3956025.18431041
#  4758271.2042221  3585339.2781791  7029319.75008576 7158151.41838419
#  6440436.26032071 3534413.96409614 4977775.30508852 7686546.97042586
#  3923015.58803389 5345401.65934426 5918994.79803269 5560022.2385093
#  5417156.92304934 6937826.34297607 3751220.54478195 3239664.64075813
#  4239165.01848012 3292026.71037748 7661300.6244239  3107767.66713566
#  6907302.31603461 3142234.48150141 4349584.79106332 4654644.91116271
#  3295783.22202777 2651622.65556102 6620295.43452686 3295783.22202777
# ...

# %%
# print("Model Evaluation by Gradient Boosting Regressor")
print("Model Evaluation by Gradient Boosting Regressor")
# print("--"*30)
print("--"*30)

# Gmse=mean_squared_error(y_test, y_predict)
Gmse=mean_squared_error(y_test, y_predict)
# Grmse=np.sqrt(Gmse)
Grmse=np.sqrt(Gmse)
# Gmae=mean_absolute_error(y_test, y_predict)
Gmae=mean_absolute_error(y_test, y_predict)
# print(f"MSE {Gmse: .2f}")
print(f"MSE {Gmse: .2f}")
# print(f"RMSE {Grmse: .2f}")
print(f"RMSE {Grmse: .2f}")
# print(f"MAE {Gmae: .2f}")
print(f"MAE {Gmae: .2f}")
# Out:
# Model Evaluation by Gradient Boosting Regressor
# ------------------------------------------------------------
# MSE  885643916923.68
# RMSE  941086.56
# MAE  693411.40

# %%
# results=np.column_stack((predicted_prices, y_test))
results=np.column_stack((predicted_prices, y_test))
# for predict, actual in results:
for predict, actual in results:
#     print(f"{round(predict, 2)} ----> {round(actual, 2)}")
    print(f"{round(predict, 2)} ----> {round(actual, 2)}")
# Out:
# 5324228.2 ----> 5530000.0
# 4444094.19 ----> 4585000.0
# 5766574.01 ----> 6083000.0
# 6170683.25 ----> 6790000.0
# 6437729.07 ----> 6293000.0
# 3906805.8 ----> 3500000.0
# 4577167.43 ----> 4893000.0
# 6293645.45 ----> 7350000.0
# 6123167.21 ----> 8190000.0
# 3621857.29 ----> 3003000.0
# 3224589.14 ----> 2800000.0
# 3918197.58 ----> 3710000.0
# 3512481.4 ----> 5110000.0
# 4205162.23 ----> 4200000.0
# 4071248.65 ----> 4900000.0
# 4620242.33 ----> 3500000.0
# 4771066.7 ----> 4200000.0
# 3015311.64 ----> 3710000.0
# 4533380.14 ----> 4007500.0
# 4652684.95 ----> 4830000.0
# 6303998.98 ----> 5460000.0
# 2579437.48 ----> 1750000.0
# 4023179.64 ----> 3010000.0
# 5693099.44 ----> 5110000.0
# 3952924.35 ----> 4480000.0
# 4844833.67 ----> 5810000.0
# 4334695.68 ----> 4795000.0
# 3831647.75 ----> 4193000.0
# 4809307.55 ----> 3773000.0
# 3964596.06 ----> 3430000.0
# 6538405.01 ----> 6650000.0
# 6525946.23 ----> 8855000.0
# 6530520.69 ----> 5950000.0
# 3711868.36 ----> 2275000.0
# ...

# %%
# print("Residuals")    
print("Residuals")    
# residual=y_test-predicted_prices
residual=y_test-predicted_prices
# print(residual)
print(residual)
# Out:
# Residuals
# 153    205771.804603
# 240    140905.806886
# 113    316425.994500
# 70     619316.748293
# 98    -144729.070369
#            ...
# 171    -37272.853642
# 329    287085.615979
# 345   -361135.585400
# 512   -912113.364849
# 525   -370366.042842
# Name: price, Length: 106, dtype: float64

# %%
# # print(f"{y_test} ----> {predicted_prices}")
# print(f"{y_test} ----> {predicted_prices}")
# sns.scatterplot(x=y_test, y=predicted_prices, color="blue", label="Actual DataPoints")
sns.scatterplot(x=y_test, y=predicted_prices, color="blue", label="Actual DataPoints")
# pt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="Red" , label="ideal line")
pt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="Red" , label="ideal line")
# pt.legend()
pt.legend()
# pt.show()
pt.show()

# %%
# sns.displot(data=residual, color="blue", label="Actual DataPoints", kde=True)
sns.displot(data=residual, color="blue", label="Actual DataPoints", kde=True)
# # pt.plot( color="Red" , label="ideal line")
# pt.plot( color="Red" , label="ideal line")
# # pt.legend()
# pt.legend()
# pt.show()
pt.show()
